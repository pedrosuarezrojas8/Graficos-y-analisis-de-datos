# %%
import pandas as pd
import numpy as np

data_location = "C:\\Users\\LEON SUAREZ\\Desktop\\VSC\\Visualizacion datos\\Proyectos de estudio\\melb_data.csv"

data = pd.read_csv(data_location)
data.head(3)
# Out:
#        Suburb          Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford     85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford  25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford     5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
#
# ...

# %%
isnull_result = data.isnull()
print(isnull_result.head(5))
# Out:
#    Suburb  Address  Rooms   Type  Price  Method  SellerG   Date  Distance  \
# 0   False    False  False  False  False   False    False  False     False
# 1   False    False  False  False  False   False    False  False     False
# 2   False    False  False  False  False   False    False  False     False
# 3   False    False  False  False  False   False    False  False     False
# 4   False    False  False  False  False   False    False  False     False
#
#    Postcode  ...  Bathroom    Car  Landsize  BuildingArea  YearBuilt  \
# 0     False  ...     False  False     False          True       True
# 1     False  ...     False  False     False         False      False
# 2     False  ...     False  False     False         False      False
# 3     False  ...     False  False     False          True       True
# 4     False  ...     False  False     False         False      False
#
#    CouncilArea  Lattitude  Longtitude  Regionname  Propertycount
# ...

# %%
is_notnull_result = data.notnull()
print(is_notnull_result.head(5))
# Out:
#    Suburb  Address  Rooms  Type  Price  Method  SellerG  Date  Distance  \
# 0    True     True   True  True   True    True     True  True      True
# 1    True     True   True  True   True    True     True  True      True
# 2    True     True   True  True   True    True     True  True      True
# 3    True     True   True  True   True    True     True  True      True
# 4    True     True   True  True   True    True     True  True      True
#
#    Postcode  ...  Bathroom   Car  Landsize  BuildingArea  YearBuilt  \
# 0      True  ...      True  True      True         False      False
# 1      True  ...      True  True      True          True       True
# 2      True  ...      True  True      True          True       True
# 3      True  ...      True  True      True         False      False
# 4      True  ...      True  True      True          True       True
#
#    CouncilArea  Lattitude  Longtitude  Regionname  Propertycount
# ...

# %%
count_nulls = isnull_result.sum()
print(count_nulls)
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
data_columnas = data.dropna(axis=1) 
print(data.shape)
print(data_columnas.shape)
# Out:
# (13580, 21)
# (13580, 17)

# %%
data_filas = data.dropna()
print(data.shape)
print(data_filas.shape)
# Out:
# (13580, 21)
# (6196, 21)

# %%
pd.value_counts(data.Car)
# Out:
# C:\Users\LEON SUAREZ\AppData\Local\Temp\ipykernel_15264\288804306.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(data.Car)
# Car
# 2.0     5591
# 1.0     5509
# 0.0     1026
# 3.0      748
# 4.0      506
# 5.0       63
# 6.0       54
# 8.0        9
# 7.0        8
# 10.0       3
# 9.0        1
# Name: count, dtype: int64

# %%
data_car_mask2 = data.Car == 2
data_car_2_count = data_car_mask2.sum()
print(data_car_2_count)
data_car_2fill = data.Car.fillna(2)
data_car_null_mask = data.Car.isnull()
data_car_null_count = data_car_null_mask.sum()
print(data_car_null_count)
# Out:
# 5591
# 62

# %%
data["Car_fill"] = data_car_2fill

# %%
data_car_mask2 = data.Car == 2
data_car_2_count = data_car_mask2.sum()
print(data_car_2_count)
data_car_2fill = data.Car.fillna(2)
data_car_null_mask = data.Car_fill.isnull()
data_car_null_count = data_car_null_mask.sum()
print(data_car_null_count)
# Out:
# 5591
# 0

# %%
data.BuildingArea.isnull().sum()
# Out:
# np.int64(6450)

# %%
data.shape
# Out:
# (13580, 22)

# %%
possible_values = data.BuildingArea(data.BuildingArea.notnull())
rng = np.random.default_rng()
fill_values_indexes = rng.integers(low = 0, high=len(possible_values), size = 1)
fill_values_index = fill_values_indexes[0]
fill_value = possible_values.iloc[fill_values_index]
